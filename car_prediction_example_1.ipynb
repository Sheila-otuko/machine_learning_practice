# %% [markdown]
# <a href="https://colab.research.google.com/github/Sheila-otuko/machine_learning_practice/blob/main/car_prediction_example_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
import seaborn as sns
sns.set()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/1.04. Real-life example.csv'
raw_data = pd.read_csv(path)
raw_data
# Out:
#               Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0               BMW    4200.0      sedan      277      2.0      Petrol
# 1     Mercedes-Benz    7900.0        van      427      2.9      Diesel
# 2     Mercedes-Benz   13300.0      sedan      358      5.0         Gas
# 3              Audi   23000.0  crossover      240      4.2      Petrol
# 4            Toyota   18300.0  crossover      120      2.0      Petrol
# ...             ...       ...        ...      ...      ...         ...
# 4340  Mercedes-Benz  125000.0      sedan        9      3.0      Diesel
# 4341            BMW    6500.0      sedan        1      3.5      Petrol
# 4342            BMW    8000.0      sedan      194      2.0      Petrol
# 4343         Toyota   14200.0      sedan       31      NaN      Petrol
# 4344     Volkswagen   13500.0        van      124      2.0      Diesel
#
#      Registration  Year              Model
# 0             yes  1991                320
# 1             yes  1999       Sprinter 212
# 2             yes  2003              S 500
# 3             yes  2007                 Q7
# 4             yes  2011              Rav 4
# ...           ...   ...                ...
# 4340          yes  2014              S 350
# 4341          yes  1999                535
# 4342          yes  1985                520
# 4343          yes  2014            Corolla
# 4344          yes  2013  T5 (Transporter)
#
# [4345 rows x 9 columns]

# %% [markdown]
# exploring the descriptive statistics of variables

# %%
raw_data.describe(include = 'all')
#include = 'all' includes all features
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year    Model
# count         4345         4345  4345.000000     4345
# unique           4            2          NaN      312
# top         Diesel          yes          NaN  E-Class
# freq          2019         3947          NaN      199
# mean           NaN          NaN  2006.550058      NaN
# std            NaN          NaN     6.719097      NaN
# min            NaN          NaN  1969.000000      NaN
# 25%            NaN          NaN  2003.000000      NaN
# 50%            NaN          NaN  2008.000000      NaN
# 75%            NaN          NaN  2012.000000      NaN
# max            NaN          NaN  2016.000000      NaN

# %% [markdown]
# determining variables of interest

# %%
data = raw_data.drop(['Model'], axis=1)
data.describe(include = 'all')
#axis 0 rows
#axis 1 columns
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4345    4173.000000   4345  4345.000000  4195.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           936            NaN   1649          NaN          NaN
# mean           NaN   19418.746935    NaN   161.237284     2.790734
# std            NaN   25584.242620    NaN   105.705797     5.066437
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    86.000000     1.800000
# 50%            NaN   11500.000000    NaN   155.000000     2.200000
# 75%            NaN   21700.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4345         4345  4345.000000
# unique           4            2          NaN
# top         Diesel          yes          NaN
# freq          2019         3947          NaN
# mean           NaN          NaN  2006.550058
# std            NaN          NaN     6.719097
# min            NaN          NaN  1969.000000
# 25%            NaN          NaN  2003.000000
# 50%            NaN          NaN  2008.000000
# 75%            NaN          NaN  2012.000000
# max            NaN          NaN  2016.000000

# %% [markdown]
# dealing with missing values

# %%
data.isnull().sum()
# Out:
# Brand             0
# Price           172
# Body              0
# Mileage           0
# EngineV         150
# Engine Type       0
# Registration      0
# Year              0
# dtype: int64

# %%
data_no_mv = data.dropna(axis=0)

# %%
data_no_mv.describe(include = 'all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         4025    4025.000000   4025  4025.000000  4025.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           880            NaN   1534          NaN          NaN
# mean           NaN   19552.308065    NaN   163.572174     2.764586
# std            NaN   25815.734988    NaN   103.394703     4.935941
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6999.000000    NaN    90.000000     1.800000
# 50%            NaN   11500.000000    NaN   158.000000     2.200000
# 75%            NaN   21900.000000    NaN   230.000000     3.000000
# max            NaN  300000.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         4025         4025  4025.000000
# unique           4            2          NaN
# top         Diesel          yes          NaN
# freq          1861         3654          NaN
# mean           NaN          NaN  2006.379627
# std            NaN          NaN     6.695595
# min            NaN          NaN  1969.000000
# 25%            NaN          NaN  2003.000000
# 50%            NaN          NaN  2007.000000
# 75%            NaN          NaN  2012.000000
# max            NaN          NaN  2016.000000

# %% [markdown]
# exploring probability distribution functions (PDFs)

# %%
sns.distplot(data_no_mv['Price'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# dealing with outliers

# %%
#outliers are values that far off from the others...remove top 1% of the code
#use quantile to fix

q = data_no_mv['Price'].quantile(0.99)
data_1 = data_no_mv[data_no_mv['Price'] <q]
data_1.describe(include = 'all')
# Out:
#              Brand          Price   Body      Mileage      EngineV  \
# count         3984    3984.000000   3984  3984.000000  3984.000000
# unique           7            NaN      6          NaN          NaN
# top     Volkswagen            NaN  sedan          NaN          NaN
# freq           880            NaN   1528          NaN          NaN
# mean           NaN   17837.117460    NaN   165.116466     2.743770
# std            NaN   18976.268315    NaN   102.766126     4.956057
# min            NaN     600.000000    NaN     0.000000     0.600000
# 25%            NaN    6980.000000    NaN    93.000000     1.800000
# 50%            NaN   11400.000000    NaN   160.000000     2.200000
# 75%            NaN   21000.000000    NaN   230.000000     3.000000
# max            NaN  129222.000000    NaN   980.000000    99.990000
#
#        Engine Type Registration         Year
# count         3984         3984  3984.000000
# unique           4            2          NaN
# top         Diesel          yes          NaN
# freq          1853         3613          NaN
# mean           NaN          NaN  2006.292922
# std            NaN          NaN     6.672745
# min            NaN          NaN  1969.000000
# 25%            NaN          NaN  2002.750000
# 50%            NaN          NaN  2007.000000
# 75%            NaN          NaN  2011.000000
# max            NaN          NaN  2016.000000

# %%
sns.distplot(data_1['Price'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data_no_mv['Mileage'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
q = data_1['Mileage'].quantile(0.99)
data_2 = data_1[data_1['Mileage']<q]

# %%
sns.distplot(data_2['Mileage'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data_no_mv['EngineV'] )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data_3 = data_2[data_2['EngineV']<6.5]

# %%
sns.distplot(data_3['EngineV'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data_no_mv['Year'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
q = data_3['Year'].quantile(0.01)
data_4 = data_3[data_3['Year']>q]

# %%
sns.distplot(data_4['Year'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data_cleaned = data_4.reset_index(drop = True)

# %%
data_cleaned.describe(include = 'all')
# Out:
#                 Brand         Price   Body     Mileage    EngineV Engine Type  \
# count              36     36.000000     36   36.000000  36.000000          36
# unique              7           NaN      6         NaN        NaN           3
# top     Mercedes-Benz           NaN  sedan         NaN        NaN      Petrol
# freq               12           NaN     23         NaN        NaN          18
# mean              NaN   3635.923611    NaN  189.055556   2.000000         NaN
# std               NaN   5649.252518    NaN  119.727057   0.523723         NaN
# min               NaN    600.000000    NaN    1.000000   1.100000         NaN
# 25%               NaN   1825.000000    NaN  107.500000   1.600000         NaN
# 50%               NaN   2250.000000    NaN  197.000000   2.000000         NaN
# 75%               NaN   3275.000000    NaN  283.250000   2.300000         NaN
# max               NaN  34999.000000    NaN  400.000000   3.800000         NaN
#
#        Registration         Year
# count            36    36.000000
# unique            1          NaN
# top             yes          NaN
# freq             36          NaN
# mean            NaN  1983.472222
# std             NaN     3.525305
# min             NaN  1969.000000
# 25%             NaN  1982.750000
# 50%             NaN  1985.000000
# 75%             NaN  1986.000000
# max             NaN  1986.000000

# %% [markdown]
# checking the OLS assumptions

# %%
#f, {ax1, ax2, ax3} = plt.plt.subplots(1, 3, sharey=True, figsize =(15,3))

# %% [markdown]
# relaxing assumptions

# %%
#the relationship appears to be more exponential than linear. to fix it we use loh

log_price = np.log(data_cleaned['Price'])
data_cleaned['log_price'] = log_price
data_cleaned
# Out:
#             Brand     Price       Body  Mileage  EngineV Engine Type  \
# 0            Audi    600.00      sedan      112      1.6      Petrol
# 1          Toyota    600.00      sedan       10      1.5      Petrol
# 2            Audi   3500.00      sedan      265      2.0      Diesel
# 3   Mercedes-Benz   2700.00      sedan      121      2.5      Diesel
# 4      Mitsubishi   5500.00  crossover        1      2.0      Petrol
# 5   Mercedes-Benz  34999.00      sedan      150      2.8      Petrol
# 6   Mercedes-Benz   1850.00      sedan      281      2.0      Diesel
# 7      Volkswagen   2500.00      sedan      324      1.6      Diesel
# 8   Mercedes-Benz   2300.00      sedan      261      2.3         Gas
# 9      Volkswagen   1550.00      hatch      130      1.3      Petrol
# 10     Volkswagen   3100.00      hatch      311      1.6         Gas
# 11     Volkswagen   2200.00      vagon      150      1.6      Petrol
# 12            BMW   4300.00      other      280      2.5      Petrol
# 13        Renault   1350.00      sedan      100      1.7      Petrol
# 14  Mercedes-Benz   6000.00      sedan      350      2.0      Diesel
# 15     Volkswagen   2200.00      hatch       33      1.9      Diesel
# 16  Mercedes-Benz   1950.00      sedan        1      2.0      Diesel
# 17     Mitsubishi   1180.00      sedan      280      1.8      Diesel
# 18            BMW   2200.00      sedan      290      1.6      Petrol
# 19  Mercedes-Benz   2990.00      sedan      300      2.8         Gas
# 20           Audi   1999.00      sedan      400      1.6      Diesel
# 21  Mercedes-Benz   2400.00      sedan      237      3.8      Petrol
# 22         Toyota   1750.00      hatch      270      1.6      Petrol
# 23            BMW   3700.00      other      110      2.5      Petrol
# 24     Volkswagen   1899.00      hatch      300      1.6         Gas
# 25  Mercedes-Benz   2650.00      sedan       30      2.3         Gas
# 26  Mercedes-Benz   7777.00      other      230      2.8      Petrol
# 27           Audi   1852.50      sedan      150      1.8      Petrol
# 28  Mercedes-Benz   3200.00      sedan      390      2.3         Gas
# 29     Volkswagen   1300.00      other       10      1.6      Diesel
# 30     Volkswagen   1950.00      hatch       94      1.1      Petrol
# 31         Toyota   1100.00        van      140      2.0         Gas
# 32            BMW   3950.00      sedan      300      2.0      Petrol
# 33  Mercedes-Benz   2500.00      sedan      200      2.3         Gas
# 34     Volkswagen   1296.75      sedan        1      1.6      Petrol
# 35            BMW   8000.00      sedan      194      2.0      Petrol
#
#    Registration  Year  log_price
# 0           yes  1980   6.396930
# 1           yes  1979   6.396930
# 2           yes  1986   8.160518
# 3           yes  1986   7.901007
# 4           yes  1986   8.612503
# 5           yes  1969  10.463075
# 6           yes  1985   7.522941
# 7           yes  1984   7.824046
# 8           yes  1978   7.740664
# 9           yes  1986   7.346010
# 10          yes  1986   8.039157
# 11          yes  1986   7.696213
# 12          yes  1985   8.366370
# 13          yes  1986   7.207860
# 14          yes  1985   8.699515
# 15          yes  1985   7.696213
# 16          yes  1979   7.575585
# 17          yes  1986   7.073270
# 18          yes  1985   7.696213
# 19          yes  1979   8.003029
# 20          yes  1986   7.600402
# 21          yes  1983   7.783224
# 22          yes  1985   7.467371
# 23          yes  1983   8.216088
# 24          yes  1984   7.549083
# 25          yes  1985   7.882315
# 26          yes  1980   8.958926
# 27          yes  1985   7.524291
# 28          yes  1985   8.070906
# 29          yes  1984   7.170120
# 30          yes  1982   7.575585
# 31          yes  1985   7.003065
# 32          yes  1986   8.281471
# 33          yes  1986   7.824046
# 34          yes  1980   7.167616
# 35          yes  1985   8.987197

# %%
data_cleaned = data_cleaned.drop(['Price'], axis = 1)

# %% [markdown]
# multicollineaity

# %%
data_cleaned.columns.values
# Out:
# array(['Brand', 'Body', 'Mileage', 'EngineV', 'Engine Type',
#        'Registration', 'Year', 'log_price'], dtype=object)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = data_cleaned[['Mileage','Year','EngineV']]
vif = pd.DataFrame()
vif['VIF'] = list((variance_inflation_factor(variables.values,i) for i in range(variables.shape[1])))
vif['features'] = variables.columns

# %%
vif

#vif = 1 no multicollinearity
#vif btn 1 & 5 or 6 0r 10 is acceptable
# Out:
#          VIF features
# 0   3.647258  Mileage
# 1  17.034136     Year
# 2  16.285012  EngineV
